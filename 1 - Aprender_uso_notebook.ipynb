# %% [markdown]
# # Generalidades
# **Author : Comision Interna para la Igualidad de Genero del ICF-UNAM**
#
# **contexto : Curso de introduccion de programacion hacia las mujeres**
#
# Este "notebook" es para aprender el uso de los "notebooks" en Python. Ovimanente, el curso es identico a un curso para todo el mundo. Solo, lo hicimos para que sea en acceso libre a su intencion. Es decir, para que se sienten la bienvenido a seguir este curso.
#
# Vamos a ver la diferencia entre una celda de texto ("Markdown") para escribir y las celdas de Codigo para ejecutar su programa. Un gran ventaja de los notebooks es que se puede ejecutar por parte. No es posible hacer eso con todos los lenguajes de programacion.

# %% [markdown]
# Pueden primero abrir una nuevacelda dentro la cual van a poder escribir. Entonces hay que ir en So **Insert**:
#
#
#
# ![image.png](attachment:image.png)
#
#
#
# y seleccionar **Insert Cell Above**

# %% [markdown]
# Se puede escoger entre varios tipos de celdas,
# ![image-2.png](attachment:image-2.png)
#
# en particular **Code** y **Markdown** cuando seleccionan con su mouse
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Markdown (basico)
#
# cuando usas **Markdown** puedes escribir innformaciones muy utiles par que el codigo sea comprensible, para otra persona, pero tambien para ti cuando léeras de nuevo el codigo despues de algunas semanas.
#
# Para editar cualquiera celda de tipo **Markdown** da un doble-clic y puedes modificar como quieres. (De hecho, para poner un texto en grueso, se tiene que usar ** palabra ** )
#
#
# Puedes ver que se usa el signo de gatito (#) para aumentar el nivel de grosor, en realidad se cambia el nivel de
#
# # Titulo (#)
# ## Sub-titulo (##)
# ### Parafo (###)
# ####  Sub-parafo (####)

# %% [markdown]
# ### Markdown (avanzado)
#
# Puedes tambien integrar ecuaciones y listas de elementos dentro de un **Markdown**
#
#
#
# - **todo lo que escribo directamente despues ** esta en grueso**
# - _todo lo que escribo directamente despues * esta en italico_
#
#
# si sabes un poco de *LaTe$\chi$* puedes tambien escribir ecuaciones entre simbolos $\$ $ or $\$\$$:
#
# $\int_{a}^{b} dx f(x) = \left[ F(x) \right]_{a}^{b}$
# $$\int_{a}^{b} dx f(x) = \left[ F(x) \right]_{a}^{b}$$

# %% [markdown]
# ## Codigo
#
# Puedes ahora abrir una nueva celda y escoger "Code". Normalmente, es el valor por default.
#
# Pueden entonces escribir cualquier bloque de codigo. En fin de ejecutar la celda, se puede clicar sobre el boton "Run"
#
# ![image.png](attachment:image.png)
#
# o igualmente usar la combinacion "Shift + Enter" en su teclado. Recomiendo este ultimo !

# %%
# Todo lo que se escribe despues de un '#' dentro de una celda
# de codigo, se queda como comentario

a = 1.
b = 2.

print(a+b)
# Out:
# 3.0

# %% [markdown]
# Una funcion que van a usar siempre es la funcion **print()** la cual permite imprimir el resultado de lo que ponen dentre de las parentesis.
#
# Pueden ahora empezar a ver los proximos notebooks. En particular, el notebook sobre la introduccion de las variables, los tipos y los arreglos
